# %% [markdown]
# 1. Python có thể làm được gì?
#
# >Python có nhiều thư viện hỗ trợ bạn có thể giải quyết nhiều vấn đề như:
#
#
# >*   Phát triển ứng dụng web:Django,...
# *   Giao diện người dùng: Tkinter,PyQt,...
# *   Trí tuệ nhân tạo(AI) và học máy(ML): Pandas, Numpy,...
# *   Phát triển ứng dụng di động: Kivy, BeeWare,...
# *   Phát triển trò chơi: PyGame,...
# *   ...
#
# 2. Hãy so sánh đặc điểm của Python với ngôn ngữ C++
#
# >Giống nhau:
#
#
# *
# *   Mục danh sách
#
# >Khác nhau:

# %%
import pandas as pd
from IPython.display import display

# Tạo dữ liệu cho bảng so sánh
data = {'So Sánh': ['Ngôn ngữ', 'Khai báo', 'Cách sử dụng', 'Phạm vi của các biến', 'Tốc độ thực thi', 'Độ phức tạp của cú pháp'],
        'C++': ['Hơi phức tạp vì nó có nhiều quy tắc cú pháp cũng như các quy ước của chương trình.', 'Nếu bạn muốn khai báo bất kỳ biến nào, thì bạn cần phải khai báo với kiểu dữ liệu của nó', 'Không dễ để viết code','Giới hạn trong các vòng hoặc khối', 'Nhanh hơn', 'Yêu cầu có sử dụng các khối và dấu chấm phẩy'],
        'Python': ['Cú pháp đơn giản, dễ học', 'Không cần khai báo bất kì kiểu dữ liệu nào với biến', 'Dễ dàng sử dụng', 'Có thể truy cập bên ngoài các vòng hoặc khối', 'Chậm hơn', 'Không yêu cầu có các khối và dấu chấm phẩy']}

# Tạo DataFrame từ dữ liệu
df = pd.DataFrame(data)

# Hiển thị bảng so sánh
display(df)
# Out:
#                    So Sánh                                                C++  \
# 0                 Ngôn ngữ  Hơi phức tạp vì nó có nhiều quy tắc cú pháp cũ...
# 1                 Khai báo  Nếu bạn muốn khai báo bất kỳ biến nào, thì bạn...
# 2             Cách sử dụng                              Không dễ để viết code
# 3     Phạm vi của các biến                  Giới hạn trong các vòng hoặc khối
# 4          Tốc độ thực thi                                          Nhanh hơn
# 5  Độ phức tạp của cú pháp       Yêu cầu có sử dụng các khối và dấu chấm phẩy
#
#                                               Python
# 0                           Cú pháp đơn giản, dễ học
# 1  Không cần khai báo bất kì kiểu dữ liệu nào với...
# 2                                    Dễ dàng sử dụng
# 3       Có thể truy cập bên ngoài các vòng hoặc khối
# 4                                           Chậm hơn
# 5         Không yêu cầu có các khối và dấu chấm phẩy
